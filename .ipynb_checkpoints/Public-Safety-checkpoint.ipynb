# %%
#Imports
import pandas as pd
import numpy as np
import math
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#Intializing the pandas dataframe
crime = pd.read_csv("public-safety.csv", index_col="Neighborhood")
#dropping the unnecessary columns from the dataset
crime = crime.drop(crime.columns[[7,8,9,10,11,12,13]], axis=1)
#creating the new column by which I will be using as the main metric
crime["Total Crime per 100 persons"] = crime['Part 1 Crime per 100 Persons (2010)'] + crime['Part 2 Crime per 100 Persons (2010)']
crime.head(5)
# Out:
#                    Sector # Population (2010)  \
# Neighborhood
# Allegheny Center          3               933
# Allegheny West            3               462
# Allentown                 6             2,500
# Arlington                 7             1,869
# Arlington Heights         7               244
#
#                    #Part 1 (Major Crime) Reports (2010)  \
# Neighborhood
# Allegheny Center                                     71
# Allegheny West                                       38
# Allentown                                           159
# Arlington                                            50
# Arlington Heights                                    19
#
#                    #Part 2 Reports (2010)  #Other Police Reports (2010)  \
# Neighborhood
# Allegheny Center                      141                            46
# Allegheny West                         49                            31
# Allentown                             252                           160
# Arlington                              84                            48
# Arlington Heights                      37                            24
#
#                    Part 1 Crime per 100 Persons (2010)  \
# Neighborhood
# Allegheny Center                                   7.6
# Allegheny West                                     8.2
# Allentown                                          6.4
# Arlington                                          2.7
# Arlington Heights                                  7.8
#
#                    Part 2 Crime per 100 Persons (2010)  \
# Neighborhood
# Allegheny Center                                  15.1
# Allegheny West                                    10.6
# Allentown                                         10.1
# Arlington                                          4.5
# Arlington Heights                                 15.2
#
#                    Total Crime per 100 persons
# Neighborhood
# Allegheny Center                          22.7
# Allegheny West                            18.8
# Allentown                                 16.5
# Arlington                                  7.2
# Arlington Heights                         23.0

# %%
#Sorting the values just to get an idea of what neighborhoods have high crime rates
crime.sort_values(by=['Part 1 Crime per 100 Persons (2010)'], ascending=False).head(5)
# Out:
#                            Sector # Population (2010)  \
# Neighborhood
# South Shore                      16                19
# Chateau                           3                11
# Strip District                   13               616
# North Shore                      16               303
# Central Business District        16             3,629
#
#                            #Part 1 (Major Crime) Reports (2010)  \
# Neighborhood
# South Shore                                                  37
# Chateau                                                      16
# Strip District                                              155
# North Shore                                                  72
# Central Business District                                   789
#
#                            #Part 2 Reports (2010)  \
# Neighborhood
# South Shore                                    60
# Chateau                                        24
# Strip District                                167
# North Shore                                    68
# Central Business District                     566
#
#                            #Other Police Reports (2010)  \
# Neighborhood
# South Shore                                          50
# Chateau                                              48
# Strip District                                      142
# North Shore                                          43
# Central Business District                           386
#
#                            Part 1 Crime per 100 Persons (2010)  \
# Neighborhood
# South Shore                                              194.7
# Chateau                                                  145.5
# Strip District                                            25.2
# North Shore                                               23.8
# Central Business District                                 21.7
#
#                            Part 2 Crime per 100 Persons (2010)  \
# Neighborhood
# South Shore                                              315.8
# Chateau                                                  218.2
# Strip District                                            27.1
# North Shore                                               22.4
# Central Business District                                 15.6
#
#                            Total Crime per 100 persons
# Neighborhood
# South Shore                                      510.5
# Chateau                                          363.7
# Strip District                                    52.3
# North Shore                                       46.2
# Central Business District                         37.3

# %%
#Sorting to see what datasets have low crime
crime.sort_values(by=['Part 2 Crime per 100 Persons (2010)'], ascending=True).head(5)
# Out:
#                      Sector # Population (2010)  \
# Neighborhood
# New Homestead               8               990
# Fairywood                   4             1,002
# Squirrel Hill North        10            11,363
# Swisshelm Park             10             1,361
# North Oakland              14            10,551
#
#                      #Part 1 (Major Crime) Reports (2010)  \
# Neighborhood
# New Homestead                                           7
# Fairywood                                               3
# Squirrel Hill North                                   148
# Swisshelm Park                                         28
# North Oakland                                         182
#
#                      #Part 2 Reports (2010)  #Other Police Reports (2010)  \
# Neighborhood
# New Homestead                             4                             9
# Fairywood                                 6                             9
# Squirrel Hill North                     110                           120
# Swisshelm Park                           14                            12
# North Oakland                           136                           160
#
#                      Part 1 Crime per 100 Persons (2010)  \
# Neighborhood
# New Homestead                                        0.7
# Fairywood                                            0.3
# Squirrel Hill North                                  1.3
# Swisshelm Park                                       2.1
# North Oakland                                        1.7
#
#                      Part 2 Crime per 100 Persons (2010)  \
# Neighborhood
# New Homestead                                        0.4
# Fairywood                                            0.6
# Squirrel Hill North                                  1.0
# Swisshelm Park                                       1.0
# North Oakland                                        1.3
#
#                      Total Crime per 100 persons
# Neighborhood
# New Homestead                                1.1
# Fairywood                                    0.9
# Squirrel Hill North                          2.3
# Swisshelm Park                               3.1
# North Oakland                                3.0

# %%
#Again sorting to see what neighborhoods have low crime
crime.sort_values(by=['Part 1 Crime per 100 Persons (2010)'], ascending=True).head(5)
# Out:
#                      Sector # Population (2010)  \
# Neighborhood
# Fairywood                   4             1,002
# New Homestead               8               990
# Lincoln Place               8             3,227
# Summer Hill                 1             1,051
# Squirrel Hill North        10            11,363
#
#                      #Part 1 (Major Crime) Reports (2010)  \
# Neighborhood
# Fairywood                                               3
# New Homestead                                           7
# Lincoln Place                                          32
# Summer Hill                                            13
# Squirrel Hill North                                   148
#
#                      #Part 2 Reports (2010)  #Other Police Reports (2010)  \
# Neighborhood
# Fairywood                                 6                             9
# New Homestead                             4                             9
# Lincoln Place                            63                            33
# Summer Hill                              22                            13
# Squirrel Hill North                     110                           120
#
#                      Part 1 Crime per 100 Persons (2010)  \
# Neighborhood
# Fairywood                                            0.3
# New Homestead                                        0.7
# Lincoln Place                                        1.0
# Summer Hill                                          1.2
# Squirrel Hill North                                  1.3
#
#                      Part 2 Crime per 100 Persons (2010)  \
# Neighborhood
# Fairywood                                            0.6
# New Homestead                                        0.4
# Lincoln Place                                        2.0
# Summer Hill                                          2.1
# Squirrel Hill North                                  1.0
#
#                      Total Crime per 100 persons
# Neighborhood
# Fairywood                                    0.9
# New Homestead                                1.1
# Lincoln Place                                3.0
# Summer Hill                                  3.3
# Squirrel Hill North                          2.3

# %%
#Creating a new sorted data set to graph the lowest crime neighborhoods
crime_data = crime.sort_values(by=['Total Crime per 100 persons'], ascending=True)
crime_data['Total Crime per 100 persons'][:10].plot(kind="bar", ylabel='Crime per 100 Persons (2010)', title='Crime per 100 Persons vs. Neighborhood')
# Out:
# <AxesSubplot:title={'center':'Crime per 100 Persons vs. Neighborhood'}, xlabel='Neighborhood', ylabel='Crime per 100 Persons (2010)'>

# %%
#Listing the top 10 data sets and their total crimes per 100 persons
crime_data['Total Crime per 100 persons'][:10]
# Out:
# Neighborhood
# Fairywood              0.9
# New Homestead          1.1
# Squirrel Hill North    2.3
# Oakwood                2.8
# Lincoln Place          3.0
# North Oakland          3.0
# Swisshelm Park         3.1
# Summer Hill            3.3
# Stanton Heights        3.4
# East Carnegie          3.5
# Name: Total Crime per 100 persons, dtype: float64

# %% [markdown]
# ### Final Analysis
# This data allowed me to see a lot about the varying crime rates in the different neighborhoods of pittsburgh. There were still many columns that I did not use in my metric that could also be used to quantify the quality of a neighborhood. However, I believe my metric covered the most general sense of safety based on the neighborhood and truly displays some of the best neighboorhoods in pittsburgh based on their safety levels. As per a scoring system Fairywood will receive 10 points, New Homestead will get 7 points, Squirrel Hill North will get 3, and the rest 1. These point values will help to determine the best neighborhood using all of our groups individual metrics together.
