# %%
#Imports
import pandas as pd
import numpy as np
import math
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
crime = pd.read_csv("public-safety.csv", index_col="Neighborhood")
crime = crime.drop(crime.columns[[7,8,9,10,11,12,13]], axis=1)
crime["Total Crime per 100 persons"] = crime['Part 1 Crime per 100 Persons (2010)'] + crime['Part 2 Crime per 100 Persons (2010)']
crime.head(5)
# Out:
#                    Sector # Population (2010)  \
# Neighborhood
# Allegheny Center          3               933
# Allegheny West            3               462
# Allentown                 6             2,500
# Arlington                 7             1,869
# Arlington Heights         7               244
#
#                    #Part 1 (Major Crime) Reports (2010)  \
# Neighborhood
# Allegheny Center                                     71
# Allegheny West                                       38
# Allentown                                           159
# Arlington                                            50
# Arlington Heights                                    19
#
#                    #Part 2 Reports (2010)  #Other Police Reports (2010)  \
# Neighborhood
# Allegheny Center                      141                            46
# Allegheny West                         49                            31
# Allentown                             252                           160
# Arlington                              84                            48
# Arlington Heights                      37                            24
#
#                    Part 1 Crime per 100 Persons (2010)  \
# Neighborhood
# Allegheny Center                                   7.6
# Allegheny West                                     8.2
# Allentown                                          6.4
# Arlington                                          2.7
# Arlington Heights                                  7.8
#
#                    Part 2 Crime per 100 Persons (2010)  \
# Neighborhood
# Allegheny Center                                  15.1
# Allegheny West                                    10.6
# Allentown                                         10.1
# Arlington                                          4.5
# Arlington Heights                                 15.2
#
#                    Total Crime per 100 persons
# Neighborhood
# Allegheny Center                          22.7
# Allegheny West                            18.8
# Allentown                                 16.5
# Arlington                                  7.2
# Arlington Heights                         23.0

# %%
crime.sort_values(by=['#Part 1 (Major Crime) Reports (2010)'], ascending=False).head(5)
# Out:
#                            Sector # Population (2010)  \
# Neighborhood
# Central Business District        16             3,629
# South Side Flats                  7             6,597
# Shadyside                        12            13,915
# East Liberty                     12             5,869
# Carrick                           5            10,113
#
#                            #Part 1 (Major Crime) Reports (2010)  \
# Neighborhood
# Central Business District                                   789
# South Side Flats                                            669
# Shadyside                                                   623
# East Liberty                                                488
# Carrick                                                     453
#
#                            #Part 2 Reports (2010)  \
# Neighborhood
# Central Business District                     566
# South Side Flats                              770
# Shadyside                                     308
# East Liberty                                  446
# Carrick                                       539
#
#                            #Other Police Reports (2010)  \
# Neighborhood
# Central Business District                           386
# South Side Flats                                    537
# Shadyside                                           285
# East Liberty                                        302
# Carrick                                             355
#
#                            Part 1 Crime per 100 Persons (2010)  \
# Neighborhood
# Central Business District                                 21.7
# South Side Flats                                          10.1
# Shadyside                                                  4.5
# East Liberty                                               8.3
# Carrick                                                    4.5
#
#                            Part 2 Crime per 100 Persons (2010)  \
# Neighborhood
# Central Business District                                 15.6
# South Side Flats                                          11.7
# Shadyside                                                  2.2
# East Liberty                                               7.6
# Carrick                                                    5.3
#
#                            Total Crime per 100 persons
# Neighborhood
# Central Business District                         37.3
# South Side Flats                                  21.8
# Shadyside                                          6.7
# East Liberty                                      15.9
# Carrick                                            9.8

# %%
crime.sort_values(by=['#Part 2 Reports (2010)'], ascending=True).head(5)
# Out:
#                Sector # Population (2010)  \
# Neighborhood
# New Homestead         8               990
# Fairywood             4             1,002
# St. Clair             7               209
# East Carnegie         4               570
# Oakwood               4             1,027
#
#                #Part 1 (Major Crime) Reports (2010)  #Part 2 Reports (2010)  \
# Neighborhood
# New Homestead                                     7                       4
# Fairywood                                         3                       6
# St. Clair                                        14                      10
# East Carnegie                                     9                      11
# Oakwood                                          14                      14
#
#                #Other Police Reports (2010)  \
# Neighborhood
# New Homestead                             9
# Fairywood                                 9
# St. Clair                                10
# East Carnegie                            11
# Oakwood                                  23
#
#                Part 1 Crime per 100 Persons (2010)  \
# Neighborhood
# New Homestead                                  0.7
# Fairywood                                      0.3
# St. Clair                                      6.7
# East Carnegie                                  1.6
# Oakwood                                        1.4
#
#                Part 2 Crime per 100 Persons (2010)  \
# Neighborhood
# New Homestead                                  0.4
# Fairywood                                      0.6
# St. Clair                                      4.8
# East Carnegie                                  1.9
# Oakwood                                        1.4
#
#                Total Crime per 100 persons
# Neighborhood
# New Homestead                          1.1
# Fairywood                              0.9
# St. Clair                             11.5
# East Carnegie                          3.5
# Oakwood                                2.8

# %%
crime.sort_values(by=['Part 1 Crime per 100 Persons (2010)'], ascending=True).head(5)
# Out:
#                      Sector # Population (2010)  \
# Neighborhood
# Fairywood                   4             1,002
# New Homestead               8               990
# Lincoln Place               8             3,227
# Summer Hill                 1             1,051
# Squirrel Hill North        10            11,363
#
#                      #Part 1 (Major Crime) Reports (2010)  \
# Neighborhood
# Fairywood                                               3
# New Homestead                                           7
# Lincoln Place                                          32
# Summer Hill                                            13
# Squirrel Hill North                                   148
#
#                      #Part 2 Reports (2010)  #Other Police Reports (2010)  \
# Neighborhood
# Fairywood                                 6                             9
# New Homestead                             4                             9
# Lincoln Place                            63                            33
# Summer Hill                              22                            13
# Squirrel Hill North                     110                           120
#
#                      Part 1 Crime per 100 Persons (2010)  \
# Neighborhood
# Fairywood                                            0.3
# New Homestead                                        0.7
# Lincoln Place                                        1.0
# Summer Hill                                          1.2
# Squirrel Hill North                                  1.3
#
#                      Part 2 Crime per 100 Persons (2010)  \
# Neighborhood
# Fairywood                                            0.6
# New Homestead                                        0.4
# Lincoln Place                                        2.0
# Summer Hill                                          2.1
# Squirrel Hill North                                  1.0
#
#                      Total Crime per 100 persons
# Neighborhood
# Fairywood                                    0.9
# New Homestead                                1.1
# Lincoln Place                                3.0
# Summer Hill                                  3.3
# Squirrel Hill North                          2.3

# %%
crime_data = crime.sort_values(by=['Total Crime per 100 persons'], ascending=True)
crime_data['Total Crime per 100 persons'][:10].plot(kind="bar", ylabel='Crime per 100 Persons (2010)')
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='Crime per 100 Persons (2010)'>

# %%
crime_data['Total Crime per 100 persons'][:10]
# Out:
# Neighborhood
# Fairywood              0.9
# New Homestead          1.1
# Squirrel Hill North    2.3
# Oakwood                2.8
# Lincoln Place          3.0
# North Oakland          3.0
# Swisshelm Park         3.1
# Summer Hill            3.3
# Stanton Heights        3.4
# East Carnegie          3.5
# Name: Total Crime per 100 persons, dtype: float64
