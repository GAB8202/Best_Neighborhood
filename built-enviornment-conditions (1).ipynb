# %% [markdown]
# # __Built-enviornment-conditions__

# %% [markdown]
# ### -Here is what the data looks like for enviornment conditions

# %%
import pandas as pd
file = pd.read_csv("built-enviornment-conditions.csv")
file
# Out:
#            Neighborhood  Sector # Population (2010) Land Area (acres)  \
# 0      Allegheny Center         3               933             134.4
# 1        Allegheny West         3               462              90.2
# 2             Allentown         6             2,500             188.8
# 3             Arlington         7             1,869             300.8
# 4     Arlington Heights         7               244              84.5
# ..                  ...       ...               ...               ...
# 85  Upper Lawrenceville        13             2,669             259.2
# 86             West End         4               254             128.0
# 87         West Oakland        14             2,604             137.6
# 88             Westwood         4             3,066             442.9
# 89              Windgap         4             1,369             265.6
#
#    Approx. Total # Parcels (2010) Approx. Total # Taxable Parcels (2010)  \
# 0                              67                                     26
# 1                             282                                    234
# 2                           1,550                                  1,402
# 3                           1,049                                    950
# 4                              10                                      7
# ..                            ...                                    ...
# 85                          1,463                                  1,365
# 86                            384                                    295
# 87                            801                                    540
# 88                          1,581                                  1,487
# 89                            716                                    668
#
#    Approx. # of Structures (2010) Approx. # Unoccupied Parcels (2010)  \
# 0                              58                                  15
# 1                             176                                  49
# 2                           1,283                                 334
# 3                           1,034                                 198
# 4                              13                                   4
# ..                            ...                                 ...
# 85                            901                                 187
# 86                            186                                 156
# 87                            140                                  82
# 88                          1,391                                 278
# 89                            749                                  92
#
#    % Good / Excellent Condition Buildings (2009)  \
# 0                                            NaN
# 1                                          72.0%
# 2                                           2.5%
# 3                                           0.3%
# 4                                            NaN
# ..                                           ...
# 85                                          6.9%
# 86                                          1.0%
# 87                                          0.6%
# 88                                         22.7%
# 89                                         14.8%
#
#    % Average Condition Buildings (2009)  ...  \
# 0                                   NaN  ...
# 1                                 22.3%  ...
# 2                                 86.9%  ...
# 3                                 97.6%  ...
# 4                                   NaN  ...
# ..                                  ...  ...
# 85                                85.6%  ...
# 86                                92.2%  ...
# 87                                89.7%  ...
# 88                                76.4%  ...
# 89                                84.4%  ...
#
#    $ Residential Bldg. Permits (2010)  # Commercial Bldg. Permits (2010)  \
# 0                                  $0                                  6
# 1                             $30,784                                  6
# 2                            $349,708                                  1
# 3                            $159,496                                  1
# 4                                  $0                                  0
# ..                                ...                                ...
# 85                           $304,522                                 11
# 86                            $14,754                                  0
# 87                            $63,786                                 24
# 88                           $415,770                                  1
# 89                           $138,050                                  0
#
#    $ Commercial Bldg. Permits (2010)  # Code Violations (2010)  \
# 0                         $6,314,000                         0
# 1                           $795,300                         3
# 2                           $350,000                       175
# 3                            $50,000                       130
# 4                                 $0                         0
# ..                               ...                       ...
# 85                        $2,419,600                        56
# 86                                $0                        10
# 87                        $9,080,856                        50
# 88                           $19,500                        25
# 89                                $0                        27
#
#    % of all Bldgs. w/ Code Violations (2010)  # Condemned Structures (2010)  \
# 0                                       0.0%                              0
# 1                                       1.7%                              1
# 2                                      13.6%                             30
# 3                                      12.6%                             10
# 4                                       0.0%                              0
# ..                                       ...                            ...
# 85                                      6.2%                             18
# 86                                      5.4%                              1
# 87                                     35.7%                              1
# 88                                      1.8%                              4
# 89                                      3.6%                              1
#
#    % of all Bldgs. Condemned (2010)  # Demolitions (2010)  \
# 0                              0.0%                     0
# 1                              0.6%                     0
# 2                              2.3%                    16
# 3                              1.0%                     7
# 4                              0.0%                     0
# ..                              ...                   ...
# 85                             2.0%                     6
# 86                             0.5%                     3
# 87                             0.7%                     0
# 88                             0.3%                     1
# 89                             0.1%                     0
#
#    # Tax Delinquent Prop. (2+ yrs.) (2010)  \
# 0                                        0
# 1                                        3
# 2                                      287
# 3                                      142
# 4                                        3
# ..                                     ...
# 85                                     105
# 86                                      40
# 87                                      92
# 88                                      65
# 89                                      33
#
#     % of Taxable Prop. Delinquent (2010)
# 0                                   0.0%
# 1                                   1.3%
# 2                                  20.5%
# 3                                  14.9%
# 4                                  42.9%
# ..                                   ...
# 85                                  7.7%
# 86                                 13.6%
# 87                                 17.0%
# 88                                  4.4%
# 89                                  4.9%
#
# [90 rows x 22 columns]

# %% [markdown]
# ### -The data below has shown that the top 15 neighborhood where have the higher percentage on both good and average condition buildings.

# %%
df = pd.read_csv("built-enviornment-conditions.csv")
df[u'% Good / Excellent Condition Buildings (2009)'] = df[u'% Good / Excellent Condition Buildings (2009)'].str.strip('%').astype(float)/100
df[u'% Average Condition Buildings (2009)'] = df[u'% Average Condition Buildings (2009)'].str.strip('%').astype(float)/100
df['%Average on Good&Average Condition Buildings'] = df[['% Good / Excellent Condition Buildings (2009)', '% Average Condition Buildings (2009)']].mean(axis=1)
df
newdata = df.sort_values("% Good / Excellent Condition Buildings (2009)", ascending=False).head(20)
df1 = newdata.loc[:,['Neighborhood','% Good / Excellent Condition Buildings (2009)','% Average Condition Buildings (2009)','%Average on Good&Average Condition Buildings']]
df1
condition = df1.sort_values("%Average on Good&Average Condition Buildings", ascending=False).head(15)
condition
# Out:
#              Neighborhood  % Good / Excellent Condition Buildings (2009)  \
# 75    Squirrel Hill North                                          0.176
# 65          Regent Square                                          0.164
# 58                Oakwood                                          0.203
# 67              Shadyside                                          0.139
# 39          Highland Park                                          0.136
# 54          New Homestead                                          0.135
# 89                Windgap                                          0.148
# 88               Westwood                                          0.227
# 55          North Oakland                                          0.154
# 33             Friendship                                          0.178
# 28           East Liberty                                          0.212
# 17  Central Lawrenceville                                          0.187
# 1          Allegheny West                                          0.720
# 56            North Shore                                          0.800
# 25         East Allegheny                                          0.209
#
#     % Average Condition Buildings (2009)  \
# 75                                 0.824
# 65                                 0.836
# 58                                 0.792
# 67                                 0.856
# 39                                 0.858
# 54                                 0.858
# 89                                 0.844
# 88                                 0.764
# 55                                 0.819
# 33                                 0.791
# 28                                 0.748
# 17                                 0.759
# 1                                  0.223
# 56                                 0.125
# 25                                 0.679
#
#     %Average on Good&Average Condition Buildings
# 75                                        0.5000
# 65                                        0.5000
# 58                                        0.4975
# 67                                        0.4975
# 39                                        0.4970
# 54                                        0.4965
# 89                                        0.4960
# 88                                        0.4955
# 55                                        0.4865
# 33                                        0.4845
# 28                                        0.4800
# 17                                        0.4730
# 1                                         0.4715
# 56                                        0.4625
# 25                                        0.4440

# %% [markdown]
# ### -The data table below has shown that the top 45 neighborhood that have the least population density.

# %%
df = pd.read_csv("built-enviornment-conditions.csv")
def con(column):
    column = column.replace(',', '')
    column = int(column)
    return column
df['Population (2010)'] = df['Population (2010)'].map(con)
df
SquareM = df['Land Area (acres)'].str.replace(',', '').astype(float)*0.0015625
df['Population Density'] = df['Population (2010)']/SquareM
df2 = df.sort_values("Population Density", ascending=True).head(45)
density = df2.loc[:,['Neighborhood','Population (2010)','Land Area (acres)','Population Density','Sector #']]
density
# Out:
#                 Neighborhood  Population (2010) Land Area (acres)  \
# 21                   Chateau                 11             245.1
# 70               South Shore                 19             135.7
# 37                      Hays                362           1,120.0
# 77                 St. Clair                209             198.4
# 56               North Shore                303             193.9
# 79            Strip District                616             389.1
# 31                 Fairywood               1002             620.2
# 54             New Homestead                990             508.2
# 86                  West End                254             128.0
# 30                    Esplen                301             147.2
# 66                 Ridgemont                483             236.2
# 26             East Carnegie                570             276.5
# 35                Glen Hazel                716             291.8
# 4          Arlington Heights                244              84.5
# 80               Summer Hill               1051             281.0
# 11                   Bon Air                808             200.3
# 46  Lincoln-Lemington-Belmar               4883           1,159.7
# 38                 Hazelwood               4317           1,013.1
# 81            Swisshelm Park               1361             307.2
# 73             Spring Garden                884             176.0
# 1             Allegheny West                462              90.2
# 45             Lincoln Place               3227             629.8
# 89                   Windgap               1369             265.6
# 60               Perry North               4050             775.7
# 14      California-Kirkbride                761             138.9
# 20            Chartiers City                477              84.5
# 57         Northview Heights               1214             200.3
# 44                   Larimer               1728             284.8
# 24          Duquesne Heights               2425             398.7
# 29                   Elliott               2381             387.8
# 3                  Arlington               1869             300.8
# 58                   Oakwood               1027             161.3
# 42             Homewood West                818             127.4
# 74     Spring Hill-City View               2648             403.2
# 5                 Banksville               4144             620.2
# 59                 Overbrook               3644             537.0
# 88                  Westwood               3066             442.9
# 0           Allegheny Center                933             134.4
# 8                Beltzhoover               1925             269.4
# 61               Perry South               4145             579.2
# 17     Central Lawrenceville               4482             616.3
# 49        Marshall-Shadeland               6043             802.6
# 65             Regent Square                928             122.9
# 64               Polish Hill               1274             163.2
# 22           Crafton Heights               3814             482.6
#
#     Population Density  Sector #
# 21           28.722970         3
# 70           89.609433        16
# 37          206.857143         8
# 77          674.193548         7
# 56         1000.103146        16
# 79         1013.209972        13
# 31         1033.989036         4
# 54         1246.753247         8
# 86         1270.000000         4
# 30         1308.695652         4
# 66         1308.721423         4
# 26         1319.349005         4
# 35         1570.390679         9
# 4          1848.047337         7
# 80         2393.736655         1
# 11         2581.727409         6
# 46         2694.765888        11
# 38         2727.154279         9
# 81         2835.416667        10
# 73         3214.545455         1
# 1          3278.048780         3
# 45         3279.263258         8
# 89         3298.795181         4
# 60         3341.498002         2
# 14         3506.407487         3
# 20         3612.781065         4
# 57         3878.981528         1
# 44         3883.146067        12
# 24         3892.651116         6
# 29         3929.448169         4
# 3          3976.595745         7
# 58         4074.891507         4
# 42         4109.262166        11
# 74         4203.174603         1
# 5          4276.297968         5
# 59         4342.942272         5
# 88         4430.435764         4
# 0          4442.857143         3
# 8          4573.125464         6
# 61         4580.110497         2
# 17         4654.356644        13
# 49         4818.739098         2
# 65         4832.546786        10
# 64         4996.078431        13
# 22         5057.936179         4

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (8,40))
plt.barh(density['Neighborhood'], density['Population Density'])
plt.title('Differences in Population Density')
plt.show()

# %% [markdown]
# ### -The data table below has shown that the two neighborhood where they are not only on the higher percentage of good and average condition buildings, also on the top 45 the least population density list.

# %%
df3 = pd.merge(condition,density,on='Neighborhood',how='inner')
df3
df3.loc[:,['Neighborhood','% Good / Excellent Condition Buildings (2009)','% Average Condition Buildings (2009)','%Average on Good&Average Condition Buildings','Population Density','Sector #']]
# Out:
#             Neighborhood  % Good / Excellent Condition Buildings (2009)  \
# 0          Regent Square                                          0.164
# 1                Oakwood                                          0.203
# 2          New Homestead                                          0.135
# 3                Windgap                                          0.148
# 4               Westwood                                          0.227
# 5  Central Lawrenceville                                          0.187
# 6         Allegheny West                                          0.720
# 7            North Shore                                          0.800
#
#    % Average Condition Buildings (2009)  \
# 0                                 0.836
# 1                                 0.792
# 2                                 0.858
# 3                                 0.844
# 4                                 0.764
# 5                                 0.759
# 6                                 0.223
# 7                                 0.125
#
#    %Average on Good&Average Condition Buildings  Population Density  Sector #
# 0                                        0.5000         4832.546786        10
# 1                                        0.4975         4074.891507         4
# 2                                        0.4965         1246.753247         8
# 3                                        0.4960         3298.795181         4
# 4                                        0.4955         4430.435764         4
# 5                                        0.4730         4654.356644        13
# 6                                        0.4715         3278.048780         3
# 7                                        0.4625         1000.103146        16

# %% [markdown]
# ### -In coclusion

# %% [markdown]
# ##### Out of all the neighborhood in pittsburgh, based on the built environment conditions data table, I would recommend choosing Regent Square as the better neighborhood since it has 10 sectors in the area.
# ##### As well as it has 16.4% excellent condition buildings in the area with 83.36% average conditon buildings. The average percentage on both excellent and average condition buildings is 50.00%, which is one of the highest since the maximum percentage on all neighborhood is 50%.
# ##### The population density is on the 2nd position on the top 45 least population density data table list, which it has a good amount of population in the area as well as a large land area which does not feel crowded when living in this area
